# %% [markdown]
# <a href="https://colab.research.google.com/github/redinbluesky/fun-coding-python-data-analysis/blob/main/11-데이터_분석_시각화_심화.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  목차
# * [Chapter 11-1 영화 데이터 심층 분석하기](#chapter11-1)

# %% [markdown]
# ## Chapter 11-1 영화 데이터 심층  분석하기 <a class="anchor" id="chapter11-1"></a>
